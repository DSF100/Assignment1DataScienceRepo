# %% [markdown]
# ## CITS2402 - Introduction to Data Science - Assignment 1.
#
# ### Comparing Demographic Trends in Australian Census Data (2021 and 2016)
#
# **Date:** August 2025.

# %% [markdown]
# ## Declaration
#
# This declaration should be completed and remain attached to the top of your submission.
#
# *I/we am/are aware of the University’s [policy on academic conduct](https://www.uwa.edu.au/policy/-/media/project/uwa/uwa/policy-library/policy/student-administration/academic-integrity/academic-integrity-policy.doc) and I declare that this assignment is entirely the work of the author(s) listed below and that suitable acknowledgement has been made for any sources of information used in preparing it. I have retained a copy for my own records.*
#
# - Name 1: Dean Shane Sing Fat
# - Student ID 1: 24537803
# - Name 2:
# - Student ID 2:
# - Name 3: Tinashe Nemacha
# - Student ID 3: 24527669
# - Date:

# %% [markdown]
# The suffix `-template` should be replaced with the corresponding student numbers. For instance, if you are doing your assignment with another person, you should rename your file as `CITS2402-Assignment-STDNO1-STDNO2.ipynb`, where 'STDNO1' and 'STDNO2' are the corresponding student numbers involved in the submission.
#
# <hr>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
print(1)

# %%
LANGUAGE_DATA_2016_C = "2016Census_G13C_AUS.csv"
LANGUAGE_DATA_2016_D = "2016Census_G13D_AUS.csv"

LANGUAGE_DATA_2021_C = "2021Census_G13C_AUS_AUS.csv"
LANGUAGE_DATA_2021_D = "2021Census_G13D_AUS_AUS.csv"
LANGUAGE_DATA_2021_E = "2021Census_G13E_AUS_AUS.csv"

# %%
list_data_2016 = []
list_data_2021 = []

with open(LANGUAGE_DATA_2016_C, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = list(csvreader)
    for name in data[0]:
        if name[0] == "P":
            list_data_2016.append(name)

with open(LANGUAGE_DATA_2016_D, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = list(csvreader)
    for name in data[0]:
        if name[0] == "P":
            list_data_2016.append(name)

with open(LANGUAGE_DATA_2021_C, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = list(csvreader)
    for name in data[0]:
        if name[0] == "P":
            list_data_2021.append(name)

with open(LANGUAGE_DATA_2021_D, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = list(csvreader)
    for name in data[0]:
        if name[0] == "P":
            list_data_2021.append(name)

with open(LANGUAGE_DATA_2021_E, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    data = list(csvreader)
    for name in data[0]:
        if name[0] == "P":
            list_data_2021.append(name)

print(len(list_data_2016))
print(len(list_data_2021))
#print(list_data_2016)
#print(list_data_2021)

i = 0
for i in range(264):
    print(list_data_2016[i] + "       " + list_data_2021[i])
# Out:
# 264
# 282
# PSEO_SEO       PSEO_SEO
# PSEO_SOLSE_VWorW       PSEO_UOLSE_VWorW
# PSEO_SOLSE_NWorNAA       PSEO_UOLSE_NWorNAA
# PSEO_SOLSE_Tot       PSEO_UOLSE_Tot
# PSEO_NS       PSEO_NS
# PSEO_Tot       PSEO_Tot
# POL_Afrikaans_SEO       POL_Afrikaans_SEO
# POL_Afrikaans_SOLSE_VWorW       POL_Afrikaans_UOLSE_VWorW
# POL_Afrikaans_SOLSE_NWorNAA       POL_Afrikaans_UOLSE_NWorNAA
# POL_Afrikaans_SOLSE_Tot       POL_Afrikaans_UOLSE_Tot
# POL_Afrikaans_NS       POL_Afrikaans_NS
# POL_Afrikaans_Tot       POL_Afrikaans_Tot
# POL_Arabic_SEO       POL_Arabic_SEO
# POL_Arabic_SOLSE_VWorW       POL_Arabic_UOLSE_VWorW
# POL_Arabic_SOLSE_NWorNAA       POL_Arabic_UOLSE_NWorNAA
# POL_Arabic_SOLSE_Tot       POL_Arabic_UOLSE_Tot
# POL_Arabic_NS       POL_Arabic_NS
# POL_Arabic_Tot       POL_Arabic_Tot
# POL_AIndLng_SEO       POL_AIndLng_SEO
# POL_AIndLng_SOLSE_VWorW       POL_AIndLng_UOLSE_VWorW
# POL_AIndLng_SOLSE_NWorNAA       POL_AIndLng_UOLSE_NWorNAA
# POL_AIndLng_SOLSE_Tot       POL_AIndLng_UOLSE_Tot
# POL_AIndLng_NS       POL_AIndLng_NS
# POL_AIndLng_Tot       POL_AIndLng_Tot
# POL_CL_Cantones_SEO       POL_CL_Canton_SEO
# POL_CL_Cantones_SOLSE_VWorW       POL_CL_Canton_UOLSE_VWorW
# POL_CL_Cantones_SOLSE_NWorNAA       POL_CL_Canton_UOLSE_NWorNAA
# POL_CL_Cantones_SOLSE_Tot       POL_CL_Canton_UOLSE_Tot
# POL_CL_Cantones_NS       POL_CL_Canton_NS
# POL_CL_Cantones_Tot       POL_CL_Canton_Tot
# POL_CL_Mandarin_SEO       POL_CL_Mandarin_SEO
# POL_CL_Mandarin_SOLSE_VWorW       POL_CL_Mandarin_UOLSE_VWorW
# POL_CL_Mandarin_SOLSE_NWorNAA       POL_CL_Mandarin_UOLSE_NWorNAA
# POL_CL_Mandarin_SOLSE_Tot       POL_CL_Mandarin_UOLSE_Tot
# POL_CL_Mandarin_NS       POL_CL_Mandarin_NS
# POL_CL_Mandarin_Tot       POL_CL_Mandarin_Tot
# POL_CL_Oth_SEO       POL_CL_Oth_SEO
# POL_CL_Oth_SOLSE_VWorW       POL_CL_Oth_UOLSE_VWorW
# POL_CL_Oth_SOLSE_NWorNAA       POL_CL_Oth_UOLSE_NWorNAA
# POL_CL_Oth_SOLSE_Tot       POL_CL_Oth_UOLSE_Tot
# POL_CL_Oth_NS       POL_CL_Oth_NS
# POL_CL_Oth_Tot       POL_CL_Oth_Tot
# POL_CL_Tot_SEO       POL_CL_Tot_SEO
# POL_CL_Tot_SOLSE_VWorW       POL_CL_Tot_UOLSE_VWorW
# POL_CL_Tot_SOLSE_NWorNAA       POL_CL_Tot_UOLSE_NWorNAA
# POL_CL_Tot_SOLSE_Tot       POL_CL_Tot_UOLSE_Tot
# POL_CL_Tot_NS       POL_CL_Tot_NS
# POL_CL_Tot_Tot       POL_CL_Tot_Tot
# POL_Croatian_SEO       POL_Croatian_SEO
# POL_Croatian_SOLSE_VWorW       POL_Croatian_UOLSE_VWorW
# POL_Croatian_SOLSE_NWorNAA       POL_Croatian_UOLSE_NWorNAA
# POL_Croatian_SOLSE_Tot       POL_Croatian_UOLSE_Tot
# POL_Croatian_NS       POL_Croatian_NS
# POL_Croatian_Tot       POL_Croatian_Tot
# POL_Dutch_SEO       POL_French_SEO
# POL_Dutch_SOLSE_VWorW       POL_French_UOLSE_VWorW
# POL_Dutch_SOLSE_NWorNAA       POL_French_UOLSE_NWorNAA
# POL_Dutch_SOLSE_Tot       POL_French_UOLSE_Tot
# POL_Dutch_NS       POL_French_NS
# POL_Dutch_Tot       POL_French_Tot
# POL_French_SEO       POL_German_SEO
# POL_French_SOLSE_VWorW       POL_German_UOLSE_VWorW
# POL_French_SOLSE_NWorNAA       POL_German_UOLSE_NWorNAA
# POL_French_SOLSE_Tot       POL_German_UOLSE_Tot
# POL_French_NS       POL_German_NS
# POL_French_Tot       POL_German_Tot
# POL_German_SEO       POL_Greek_SEO
# POL_German_SOLSE_VWorW       POL_Greek_UOLSE_VWorW
# POL_German_SOLSE_NWorNAA       POL_Greek_UOLSE_NWorNAA
# POL_German_SOLSE_Tot       POL_Greek_UOLSE_Tot
# POL_German_NS       POL_Greek_NS
# POL_German_Tot       POL_Greek_Tot
# POL_Greek_SEO       POL_IAL_Bengali_SEO
# POL_Greek_SOLSE_VWorW       POL_IAL_Bengali_UOLSE_VWorW
# POL_Greek_SOLSE_NWorNAA       POL_IAL_Bengali_UOLSE_NWorNAA
# POL_Greek_SOLSE_Tot       POL_IAL_Bengali_UOLSE_Tot
# POL_Greek_NS       POL_IAL_Bengali_NS
# POL_Greek_Tot       POL_IAL_Bengali_Tot
# POL_IAL_Bengali_SEO       POL_IAL_Guj_SEO
# POL_IAL_Bengali_SOLSE_VWorW       POL_IAL_Guj_UOLSE_VWorW
# POL_IAL_Bengali_SOLSE_NWorNAA       POL_IAL_Guj_UOLSE_NWorNAA
# POL_IAL_Bengali_SOLSE_Tot       POL_IAL_Guj_UOLSE_Tot
# POL_IAL_Bengali_NS       POL_IAL_Guj_NS
# POL_IAL_Bengali_Tot       POL_IAL_Guj_Tot
# POL_IAL_Hindi_SEO       POL_IAL_Hindi_SEO
# POL_IAL_Hindi_SOLSE_VWorW       POL_IAL_Hindi_UOLSE_VWorW
# POL_IAL_Hindi_SOLSE_NWorNAA       POL_IAL_Hindi_UOLSE_NWorNAA
# POL_IAL_Hindi_SOLSE_Tot       POL_IAL_Hindi_UOLSE_Tot
# POL_IAL_Hindi_NS       POL_IAL_Hindi_NS
# POL_IAL_Hindi_Tot       POL_IAL_Hindi_Tot
# POL_IAL_Punjabi_SEO       POL_IAL_Nepali_SEO
# POL_IAL_Punjabi_SOLSE_VWorW       POL_IAL_Nepali_UOLSE_VWorW
# POL_IAL_Punjabi_SOLSE_NWorNAA       POL_IAL_Nepali_UOLSE_NWorNAA
# POL_IAL_Punjabi_SOLSE_Tot       POL_IAL_Nepali_UOLSE_Tot
# POL_IAL_Punjabi_NS       POL_IAL_Nepali_NS
# POL_IAL_Punjabi_Tot       POL_IAL_Nepali_Tot
# POL_IAL_Sinhalese_SEO       POL_IAL_Punjabi_SEO
# POL_IAL_Sinhalese_SOLSE_VWorW       POL_IAL_Punjabi_UOLSE_VWorW
# POL_IAL_Sinhale_SOLSE_NWorNAA       POL_IAL_Punjabi_UOLSE_NWorNAA
# POL_IAL_Sinhalese_SOLSE_Tot       POL_IAL_Punjabi_UOLSE_Tot
# POL_IAL_Sinhalese_NS       POL_IAL_Punjabi_NS
# POL_IAL_Sinhalese_Tot       POL_IAL_Punjabi_Tot
# POL_IAL_Urdu_SEO       POL_IAL_Sinhal_SEO
# POL_IAL_Urdu_SOLSE_VWorW       POL_IAL_Sinhal_UOLSE_VWorW
# POL_IAL_Urdu_SOLSE_NWorNAA       POL_IAL_Sinhal_UOLSE_NWorNAA
# POL_IAL_Urdu_SOLSE_Tot       POL_IAL_Sinhal_UOLSE_Tot
# POL_IAL_Urdu_NS       POL_IAL_Sinhal_NS
# POL_IAL_Urdu_Tot       POL_IAL_Sinhal_Tot
# POL_IAL_Oth_SEO       POL_IAL_Urdu_SEO
# POL_IAL_Oth_SOLSE_VWorW       POL_IAL_Urdu_UOLSE_VWorW
# POL_IAL_Oth_SOLSE_NWorNAA       POL_IAL_Urdu_UOLSE_NWorNAA
# POL_IAL_Oth_SOLSE_Tot       POL_IAL_Urdu_UOLSE_Tot
# POL_IAL_Oth_NS       POL_IAL_Urdu_NS
# POL_IAL_Oth_Tot       POL_IAL_Urdu_Tot
# POL_IAL_Tot_SEO       POL_IAL_Oth_SEO
# POL_IAL_Tot_SOLSE_VWorW       POL_IAL_Oth_UOLSE_VWorW
# POL_IAL_Tot_SOLSE_NWorNAA       POL_IAL_Oth_UOLSE_NWorNAA
# POL_IAL_Tot_SOLSE_Tot       POL_IAL_Oth_UOLSE_Tot
# POL_IAL_Tot_NS       POL_IAL_Oth_NS
# POL_IAL_Tot_Tot       POL_IAL_Oth_Tot
# POL_Italian_SEO       POL_IAL_Tot_SEO
# POL_Italian_SOLSE_VWorW       POL_IAL_Tot_UOLSE_VWorW
# POL_Italian_SOLSE_NWorNAA       POL_IAL_Tot_UOLSE_NWorNAA
# POL_Italian_SOLSE_Tot       POL_IAL_Tot_UOLSE_Tot
# POL_Italian_NS       POL_IAL_Tot_NS
# POL_Italian_Tot       POL_IAL_Tot_Tot
# POL_Japanese_SEO       POL_Italian_SEO
# POL_Japanese_SOLSE_VWorW       POL_Italian_UOLSE_VWorW
# POL_Japanese_SOLSE_NWorNAA       POL_Italian_UOLSE_NWorNAA
# POL_Japanese_SOLSE_Tot       POL_Italian_UOLSE_Tot
# POL_Japanese_NS       POL_Italian_NS
# POL_Japanese_Tot       POL_Italian_Tot
# POL_Korean_SEO       POL_Japan_SEO
# POL_Korean_SOLSE_VWorW       POL_Japan_UOLSE_VWorW
# POL_Korean_SOLSE_NWorNAA       POL_Japan_UOLSE_NWorNAA
# POL_Korean_SOLSE_Tot       POL_Japan_UOLSE_Tot
# POL_Korean_NS       POL_Japan_NS
# POL_Korean_Tot       POL_Japan_Tot
# POL_Macedonian_SEO       POL_Khmer_SEO
# POL_Macedonian_SOLSE_VWorW       POL_Khmer_UOLSE_VWorW
# POL_Macedonian_SOLSE_NWorNAA       POL_Khmer_UOLSE_NWorNAA
# POL_Macedonian_SOLSE_Tot       POL_Khmer_UOLSE_Tot
# POL_Macedonian_NS       POL_Khmer_NS
# POL_Macedonian_Tot       POL_Khmer_Tot
# POL_Maltese_SEO       POL_Korean_SEO
# POL_Maltese_SOLSE_VWorW       POL_Korean_UOLSE_VWorW
# POL_Maltese_SOLSE_NWorNAA       POL_Korean_UOLSE_NWorNAA
# POL_Maltese_SOLSE_Tot       POL_Korean_UOLSE_Tot
# POL_Maltese_NS       POL_Korean_NS
# POL_Maltese_Tot       POL_Korean_Tot
# POL_Persian_ED_SEO       POL_Macedon_SEO
# POL_Persian_ED_SOLSE_VWorW       POL_Macedon_UOLSE_VWorW
# POL_Persian_ED_SOLSE_NWorNAA       POL_Macedon_UOLSE_NWorNAA
# POL_Persian_ED_SOLSE_Tot       POL_Macedon_UOLSE_Tot
# POL_Persian_ED_NS       POL_Macedon_NS
# POL_Persian_ED_Tot       POL_Macedon_Tot
# POL_Polish_SEO       POL_Malayalam_SEO
# POL_Polish_SOLSE_VWorW       POL_Malayalam_UOLSE_VWorW
# POL_Polish_SOLSE_NWorNAA       POL_Malayalam_UOLSE_NWorNAA
# POL_Polish_SOLSE_Tot       POL_Malayalam_UOLSE_Tot
# POL_Polish_NS       POL_Malayalam_NS
# POL_Polish_Tot       POL_Malayalam_Tot
# POL_Russian_SEO       POL_Persian_ED_SEO
# POL_Russian_SOLSE_VWorW       POL_Persian_ED_UOLSE_VWorW
# POL_Russian_SOLSE_NWorNAA       POL_Persian_ED_UOLSE_NWorNAA
# POL_Russian_SOLSE_Tot       POL_Persian_ED_UOLSE_Tot
# POL_Russian_NS       POL_Persian_ED_NS
# POL_Russian_Tot       POL_Persian_ED_Tot
# POL_Samoan_SEO       POL_Polish_SEO
# POL_Samoan_SOLSE_VWorW       POL_Polish_UOLSE_VWorW
# POL_Samoan_SOLSE_NWorNAA       POL_Polish_UOLSE_NWorNAA
# POL_Samoan_SOLSE_Tot       POL_Polish_UOLSE_Tot
# POL_Samoan_NS       POL_Polish_NS
# POL_Samoan_Tot       POL_Polish_Tot
# POL_Serbian_SEO       POL_Portuguese_SEO
# POL_Serbian_SOLSE_VWorW       POL_Portuguese_UOLSE_VWorW
# POL_Serbian_SOLSE_NWorNAA       POL_Portuguese_UOLSE_NWorNAA
# POL_Serbian_SOLSE_Tot       POL_Portuguese_UOLSE_Tot
# POL_Serbian_NS       POL_Portuguese_NS
# POL_Serbian_Tot       POL_Portuguese_Tot
# POL_SAL_Filipino_SEO       POL_Russian_SEO
# POL_SAL_Filipino_SOLSE_VWorW       POL_Russian_UOLSE_VWorW
# POL_SAL_Filipin_SOLSE_NWorNAA       POL_Russian_UOLSE_NWorNAA
# POL_SAL_Filipino_SOLSE_Tot       POL_Russian_UOLSE_Tot
# POL_SAL_Filipino_NS       POL_Russian_NS
# POL_SAL_Filipino_Tot       POL_Russian_Tot
# POL_SAL_Indonesian_SEO       POL_Samoan_SEO
# POL_SAL_Indonesia_SOLSE_VWorW       POL_Samoan_UOLSE_VWorW
# POL_SAL_Indones_SOLSE_NWorNAA       POL_Samoan_UOLSE_NWorNAA
# POL_SAL_Indonesian_SOLSE_Tot       POL_Samoan_UOLSE_Tot
# POL_SAL_Indonesian_NS       POL_Samoan_NS
# POL_SAL_Indonesian_Tot       POL_Samoan_Tot
# POL_SAL_Tagalog_SEO       POL_Serbian_SEO
# POL_SAL_Tagalog_SOLSE_VWorW       POL_Serbian_UOLSE_VWorW
# POL_SAL_Tagalog_SOLSE_NWorNAA       POL_Serbian_UOLSE_NWorNAA
# POL_SAL_Tagalog_SOLSE_Tot       POL_Serbian_UOLSE_Tot
# POL_SAL_Tagalog_NS       POL_Serbian_NS
# POL_SAL_Tagalog_Tot       POL_Serbian_Tot
# POL_SAL_Oth_SEO       POL_SAL_Filipin_SEO
# POL_SAL_Oth_SOLSE_VWorW       POL_SAL_Filipin_UOLSE_VWorW
# POL_SAL_Oth_SOLSE_NWorNAA       POL_SAL_Filipin_UOLSE_NWorNAA
# POL_SAL_Oth_SOLSE_Tot       POL_SAL_Filipin_UOLSE_Tot
# POL_SAL_Oth_NS       POL_SAL_Filipin_NS
# POL_SAL_Oth_Tot       POL_SAL_Filipin_Tot
# POL_SAL_Tot_SEO       POL_SAL_Indon_SEO
# POL_SAL_Tot_SOLSE_VWorW       POL_SAL_Indon_UOLSE_VWorW
# POL_SAL_Tot_SOLSE_NWorNAA       POL_SAL_Indon_UOLSE_NWorNAA
# POL_SAL_Tot_SOLSE_Tot       POL_SAL_Indon_UOLSE_Tot
# POL_SAL_Tot_NS       POL_SAL_Indon_NS
# POL_SAL_Tot_Tot       POL_SAL_Indon_Tot
# POL_Spanish_SEO       POL_SAL_Tagalog_SEO
# POL_Spanish_SOLSE_VWorW       POL_SAL_Tagalog_UOLSE_VWorW
# POL_Spanish_SOLSE_NWorNAA       POL_SAL_Tagalog_UOLSE_NWorNAA
# POL_Spanish_SOLSE_Tot       POL_SAL_Tagalog_UOLSE_Tot
# POL_Spanish_NS       POL_SAL_Tagalog_NS
# POL_Spanish_Tot       POL_SAL_Tagalog_Tot
# POL_Tamil_SEO       POL_SAL_Oth_SEO
# POL_Tamil_SOLSE_VWorW       POL_SAL_Oth_UOLSE_VWorW
# POL_Tamil_SOLSE_NWorNAA       POL_SAL_Oth_UOLSE_NWorNAA
# POL_Tamil_SOLSE_Tot       POL_SAL_Oth_UOLSE_Tot
# POL_Tamil_NS       POL_SAL_Oth_NS
# POL_Tamil_Tot       POL_SAL_Oth_Tot
# POL_Thai_SEO       POL_SAL_Tot_SEO
# POL_Thai_SOLSE_VWorW       POL_SAL_Tot_UOLSE_VWorW
# POL_Thai_SOLSE_NWorNAA       POL_SAL_Tot_UOLSE_NWorNAA
# POL_Thai_SOLSE_Tot       POL_SAL_Tot_UOLSE_Tot
# POL_Thai_NS       POL_SAL_Tot_NS
# POL_Thai_Tot       POL_SAL_Tot_Tot
# POL_Turkish_SEO       POL_Spanish_SEO
# POL_Turkish_SOLSE_VWorW       POL_Spanish_UOLSE_VWorW
# POL_Turkish_SOLSE_NWorNAA       POL_Spanish_UOLSE_NWorNAA
# POL_Turkish_SOLSE_Tot       POL_Spanish_UOLSE_Tot
# POL_Turkish_NS       POL_Spanish_NS
# POL_Turkish_Tot       POL_Spanish_Tot
# POL_Vietnamese_SEO       POL_Tamil_SEO
# POL_Vietnamese_SOLSE_VWorW       POL_Tamil_UOLSE_VWorW
# POL_Vietnamese_SOLSE_NWorNAA       POL_Tamil_UOLSE_NWorNAA
# POL_Vietnamese_SOLSE_Tot       POL_Tamil_UOLSE_Tot
# POL_Vietnamese_NS       POL_Tamil_NS
# POL_Vietnamese_Tot       POL_Tamil_Tot
# POL_Oth_SEO       POL_Thai_SEO
# POL_Oth_SOLSE_VWorW       POL_Thai_UOLSE_VWorW
# POL_Oth_SOLSE_NWorNAA       POL_Thai_UOLSE_NWorNAA
# POL_Oth_SOLSE_Tot       POL_Thai_UOLSE_Tot
# POL_Oth_NS       POL_Thai_NS
# POL_Oth_Tot       POL_Thai_Tot
# POL_Tot_SEO       POL_Turkish_SEO
# POL_Tot_SOLSE_VWorW       POL_Turkish_UOLSE_VWorW
# POL_Tot_SOLSE_NWorNAA       POL_Turkish_UOLSE_NWorNAA
# POL_Tot_SOLSE_Tot       POL_Turkish_UOLSE_Tot
# POL_Tot_NS       POL_Turkish_NS
# POL_Tot_Tot       POL_Turkish_Tot
# P_LSatH_NS_SEO       POL_Vietnamese_SEO
# P_LSatH_NS_SOLSE_VWorW       POL_Vietnamese_UOLSE_VWorW
# P_LSatH_NS_SOLSE_NWorNAA       POL_Vietnamese_UOLSE_NWorNAA
# P_LSatH_NS_SOLSE_Tot       POL_Vietnamese_UOLSE_Tot
# P_LSatH_NS_NS       POL_Vietnamese_NS
# P_LSatH_NS_Tot       POL_Vietnamese_Tot
# P_Tot_SEO       POL_Oth_SEO
# P_Tot_SOLSE_VWorW       POL_Oth_UOLSE_VWorW
# P_Tot_SOLSE_NWorNAA       POL_Oth_UOLSE_NWorNAA
# P_Tot_SOLSE_Tot       POL_Oth_UOLSE_Tot
# P_Tot_NS       POL_Oth_NS
# P_Tot_Tot       POL_Oth_Tot
